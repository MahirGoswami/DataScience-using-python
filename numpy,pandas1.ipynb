# %%
import pandas as pd
import numpy as np
dd=pd.DataFrame(np.random.randint(1,100,(5,3)),index=["elm1","elm2","elm3","elm4","elm5"],columns=["productId","productname","productprice"])
dd
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_9300\3333466776.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#       productId  productname  productprice
# elm1         75           89            77
# elm2         25           68            96
# elm3         17           66             2
# elm4         25           28            46
# elm5         33           88            53

# %%
dd.loc["elm1"]
# Out:
# productId       75
# productname     89
# productprice    77
# Name: elm1, dtype: int32

# %%
dd.loc["elm2"]
# Out:
# productId       25
# productname     68
# productprice    96
# Name: elm2, dtype: int32

# %%
dd.loc["elm3"]
# Out:
# productId       17
# productname     66
# productprice     2
# Name: elm3, dtype: int32

# %%
dd.loc["elm4"]
# Out:
# productId       25
# productname     28
# productprice    46
# Name: elm4, dtype: int32

# %%
dd.loc["elm5"]
# Out:
# productId       33
# productname     88
# productprice    53
# Name: elm5, dtype: int32

# %%
dd["productId"]
# Out:
# elm1    75
# elm2    25
# elm3    17
# elm4    25
# elm5    33
# Name: productId, dtype: int32

# %%
dd["productname"]
# Out:
# elm1    89
# elm2    68
# elm3    66
# elm4    28
# elm5    88
# Name: productname, dtype: int32

# %%
dd["productprice"]
# Out:
# elm1    77
# elm2    96
# elm3     2
# elm4    46
# elm5    53
# Name: productprice, dtype: int32

# %%
dd.loc["elm3":]
# Out:
#       productId  productname  productprice
# elm3         17           66             2
# elm4         25           28            46
# elm5         33           88            53

# %%
dd.loc["elm2":,["productprice"]]
# Out:
#       productprice
# elm2            96
# elm3             2
# elm4            46
# elm5            53

# %%
dd.iloc[1:,[2]]
# Out:
#       productprice
# elm2            96
# elm3             2
# elm4            46
# elm5            53

# %%
dd.iloc[1:4,[2]]
# Out:
#       productprice
# elm2            96
# elm3             2
# elm4            46

# %%
dd.iloc[1:4,[0,1]]
# Out:
#       productId  productname
# elm2         25           68
# elm3         17           66
# elm4         25           28

# %%
dd.iloc[0:3,[2]]
# Out:
#       productprice
# elm1            77
# elm2            96
# elm3             2

# %%
dd.loc['elm1':'elm2',dd.columns!='productprice']
# Out:
#       productId  productname
# elm1         75           89
# elm2         25           68

# %%
dd.iloc[1:3]['productprice']
# Out:
# elm2    96
# elm3     2
# Name: productprice, dtype: int32

# %%
dd=pd.DataFrame(np.random.randint(1,100,(5,3)),index=["mahir","heet","yash","meet","mihir"],columns=["python","datascience","DBMS"])
dd
# Out:
#        python  datascience  DBMS
# mahir      50           56    18
# heet       62           98    27
# yash       76           66     8
# meet        5           74    41
# mihir       6            3    37

# %%
dd["python"]>60
# Out:
# mahir    False
# heet      True
# yash      True
# meet     False
# mihir    False
# Name: python, dtype: bool

# %%
dd[dd["python"]>60]
# Out:
# Empty DataFrame
# Columns: [python, datascience, DBMS]
# Index: []

# %%
dd[dd["python"]>60]
dd
# Out:
#        python  datascience  DBMS
# mahir      50           56    18
# heet       41           98    27
# yash       41           66     8
# meet        5           74    41
# mihir       6            3    37

# %%
dd.loc[dd["python"]>60,"python"]=41
dd
# Out:
#        python  datascience  DBMS
# mahir      50           56    18
# heet       41           98    27
# yash       41           66     8
# meet        5           74    41
# mihir       6            3    37

# %%
dd+2
# Out:
#        python  datascience  DBMS
# mahir      52           58    20
# heet       43          100    29
# yash       43           68    10
# meet        7           76    43
# mihir       8            5    39

# %%
dd
# Out:
#        python  datascience  DBMS
# mahir      50           56    18
# heet       41           98    27
# yash       41           66     8
# meet        5           74    41
# mihir       6            3    37

# %%
dd1=dd+10
dd1
# Out:
#        python  datascience  DBMS
# mahir      60           66    28
# heet       51          108    37
# yash       51           76    18
# meet       15           84    51
# mihir      16           13    47

# %%
dd1
# Out:
#        python  datascience  DBMS
# mahir      60           66    28
# heet       51          108    37
# yash       51           76    18
# meet       15           84    51
# mihir      16           13    47

# %%
dd1>100
# Out:
#        python  datascience   DBMS
# mahir   False        False  False
# heet    False         True  False
# yash    False        False  False
# meet    False        False  False
# mihir   False        False  False

# %%
dd1.loc[dd1["python"]>100,["python"]]=100
dd1
# Out:
#        python  datascience  DBMS
# mahir      60           66    28
# heet       51          108    37
# yash       51           76    18
# meet       15           84    51
# mihir      16           13    47

# %%
dd1[dd1>100]=100
dd1
# Out:
#        python  datascience  DBMS
# mahir      60           66    28
# heet       51          100    37
# yash       51           76    18
# meet       15           84    51
# mihir      16           13    47

# %%
dd
# Out:
#        python  datascience  DBMS
# mahir      50           56    18
# heet       41           98    27
# yash       41           66     8
# meet        5           74    41
# mihir       6            3    37

# %%
dd1[(dd1['python']>50) & (dd1['datascience']>60)]
# Out:
#        python  datascience  DBMS
# mahir      60           66    28
# heet       51          100    37
# yash       51           76    18

# %%
dd1[dd1.index.str.startswith('m')]
# Out:
#        python  datascience  DBMS
# mahir      60           66    28
# meet       15           84    51
# mihir      16           13    47

# %%
dd1[dd1.index.str.endswith('t')]
# Out:
#       python  datascience  DBMS
# heet      51          100    37
# meet      15           84    51

# %%
dd1["total"]=((dd1["python"]+dd1["datascience"]+dd1["DBMS"]))
dd1
# Out:
#        python  datascience  DBMS  total
# mahir      60           66    28    154
# heet       51          100    37    188
# yash       51           76    18    145
# meet       15           84    51    150
# mihir      16           13    47     76

# %%
dd1["percentage"]=(((dd1["python"]+dd1["datascience"]+dd1["DBMS"])/300)*100)
dd1
# Out:
#        python  datascience  DBMS  total  percentage
# mahir      60           66    28    154   51.333333
# heet       51          100    37    188   62.666667
# yash       51           76    18    145   48.333333
# meet       15           84    51    150   50.000000
# mihir      16           13    47     76   25.333333

# %%
dd1["result"]=dd1["percentage"]>40
dd1
# Out:
#        python  datascience  DBMS  total  percentage  result
# mahir      60           66    28    154   51.333333    True
# heet       51          100    37    188   62.666667    True
# yash       51           76    18    145   48.333333    True
# meet       15           84    51    150   50.000000    True
# mihir      16           13    47     76   25.333333   False

# %%
dd1.loc[dd1["percentage"]>40,'result']="pass"
dd1
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_9300\2724139309.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'pass' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   dd1.loc[dd1["percentage"]>40,'result']="pass"
#        python  datascience  DBMS  total  percentage result
# mahir      60           66    28    154   51.333333   pass
# heet       51          100    37    188   62.666667   pass
# yash       51           76    18    145   48.333333   pass
# meet       15           84    51    150   50.000000   pass
# mihir      16           13    47     76   25.333333  False

# %%
dd1.loc[dd1["percentage"]<40,"result"]="fail"
dd1
# Out:
#        python  datascience  DBMS  total  percentage result
# mahir      60           66    28    154   51.333333   pass
# heet       51          100    37    188   62.666667   pass
# yash       51           76    18    145   48.333333   pass
# meet       15           84    51    150   50.000000   pass
# mihir      16           13    47     76   25.333333   fail

# %%
dd1["result"]=np.where(dd1["percentage"]<40,"fail","pass")
dd1
# Out:
#        python  datascience  DBMS  total  percentage result
# mahir      60           66    28    154   51.333333   pass
# heet       51          100    37    188   62.666667   pass
# yash       51           76    18    145   48.333333   pass
# meet       15           84    51    150   50.000000   pass
# mihir      16           13    47     76   25.333333   fail

# %%
dd1["result"]=np.where(dd1["percentage"]<40,"fail","pass")
dd1
# Out:
#        python  datascience  DBMS  total  percentage result
# mahir      60           66    28    154   51.333333   pass
# heet       51          100    37    188   62.666667   pass
# yash       51           76    18    145   48.333333   pass
# meet       15           84    51    150   50.000000   pass
# mihir      16           13    47     76   25.333333   fail

# %%
dd1.loc[dd1["percentage"]>40,"Grade"]="B"
dd1.loc[dd1["percentage"]>60,"Grade"]="A"
dd1.loc[dd1["percentage"]<35,"Grade"]="F"
dd1.loc[dd1["percentage"]>90,"Grade"]="AA+"


dd1
# Out:
#        python  datascience  DBMS  total  percentage result Grade
# mahir      60           66    28    154   51.333333   pass     B
# heet       51          100    37    188   62.666667   pass     A
# yash       51           76    18    145   48.333333   pass     B
# meet       15           84    51    150   50.000000   pass     B
# mihir      16           13    47     76   25.333333   fail     F

# %%
dd1
# Out:
#        python  datascience  DBMS  total  percentage result Grade
# mahir      60           66    28    154   51.333333   pass     B
# heet       51          100    37    188   62.666667   pass     A
# yash       51           76    18    145   48.333333   pass     B
# meet       15           84    51    150   50.000000   pass     B
# mihir      16           13    47     76   25.333333   fail     F

# %%
dd1.describe()
# Out:
#           python  datascience       DBMS       total  percentage
# count   5.000000     5.000000   5.000000    5.000000    5.000000
# mean   38.600000    67.800000  36.200000  142.600000   47.533333
# std    21.407942    33.063575  13.553597   40.887651   13.629217
# min    15.000000    13.000000  18.000000   76.000000   25.333333
# 25%    16.000000    66.000000  28.000000  145.000000   48.333333
# 50%    51.000000    76.000000  37.000000  150.000000   50.000000
# 75%    51.000000    84.000000  47.000000  154.000000   51.333333
# max    60.000000   100.000000  51.000000  188.000000   62.666667
